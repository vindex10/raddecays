# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams["figure.figsize"] = 8,12

# %%
pd.read_csv("initE.dat")
# Out:
#      -0.00973136
# 0      -0.001684
# 1      -0.002631
# 2      -0.001068
# 3      -0.017993
# 4      -0.010352
# 5      -0.013453
# 6      -0.007717
# 7      -0.004418
# 8      -0.013570
# 9      -0.010859
# 10     -0.011899
# 11     -0.010752
# 12     -0.003718
# 13     -0.002051
# 14     -0.012134
# 15     -0.010136
# 16     -0.010263
# 17     -0.010755
# 18     -0.006772
# 19     -0.007589
# 20     -0.004069
# 21     -0.003829
# 22     -0.006797
# 23     -0.009100
# 24     -0.011878
# 25     -0.017007
# 26     -0.014138
# 27     -0.002155
# 28     -0.009752
# 29     -0.004880
# ..           ...
# 969    -0.006108
# 970    -0.014984
# 971    -0.000129
# 972    -0.003376
# 973    -0.001257
# 974    -0.008078
# 975    -0.010435
# 976    -0.002330
# 977    -0.019657
# 978    -0.006124
# 979    -0.020396
# 980    -0.006627
# 981    -0.000592
# 982    -0.008087
# 983    -0.020660
# 984    -0.001092
# 985    -0.017154
# 986    -0.001008
# 987    -0.021742
# 988    -0.008849
# ...
